# %% [markdown]
# <b>Структура базы данных<b>

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
img = np.asarray(Image.open('Screenshot_1.png'))
plt.imshow(img)

# %% [markdown]
# В изначальной таблице поля относящиеся к адресу клиента занимали несколько столбоцов в самой таблице клиента, поэтому они были вынесены в отделюную таблицу.
#
# Так же в таблице транзакций содержалась полная информация о доставляемом товаре, что нарушо 3 НФ, поэтому товар был вынесен в отделюную сущность.
#
# Я не уверен что занчат цены в изначальной таблице, поэтому оставил обе их в таблице транзакции. Если одна из этих цен - закупочная цена товара, а другая, на пример, - цена по которой товар куплен, то закупочную цену надо было бы вынести в таблицу товара, а цену покупки оставить в транзакции.

# %% [markdown]
# <b>Скрипт загрузки данных и создания таблиц находится в файлах репозитория</b>
